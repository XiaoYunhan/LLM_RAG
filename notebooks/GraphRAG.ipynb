# %%
import numpy as np
import pandas as pd

# read parquet file
df = pd.read_parquet('../ragtest/output/relationships.parquet')
df
# Out:
#                                       id  human_readable_id  \
# 0   614980b1-0806-481a-8bc4-3862839a38a5                  0
# 1   19356984-0ee9-4604-93cc-1698f5e89b06                  1
# 2   21f80279-4ad7-4b18-9ffd-17b135e67f86                  2
# 3   eba2a529-964d-4c88-9f5d-9582cf63c105                  3
# 4   290a7152-179e-4dd8-8dec-2f78091daf37                  4
# ..                                   ...                ...
# 72  12322350-be70-4e2a-918d-65c9b69eb734                 72
# 73  e1b82c86-fd9c-484b-afc6-79878979f61c                 73
# 74  9491846c-1f25-4258-a197-26334a665997                 74
# 75  c3caa336-d64b-43b7-84ed-213318687abf                 75
# 76  f3d06ca2-6afe-4f41-939e-3c098b4423a9                 76
#
#                source                    target  \
# 0             SCROOGE              JACOB MARLEY
# 1             SCROOGE                     GHOST
# 2             SCROOGE            CHRISTMAS EVES
# ...
